# %% [markdown]
# # ⚠️ Este arquivo foi substituído
#
# **Este notebook foi migrado de Ollama para vLLM.**
#
# Por favor, abra o arquivo atualizado:
#
# ## 👉 [`LAB1_Self_RAG_vLLM.ipynb`](./LAB1_Self_RAG_vLLM.ipynb)
#
# ---
#
# *MBA em RAG & CAG Aplicados a Direito e Segurança Pública · Aula 8*
